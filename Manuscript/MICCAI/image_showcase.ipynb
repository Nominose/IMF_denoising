# %%
import sys
sys.path.append('/gpfs/work/aac/xingyiyao23/Code')

import os
import nibabel as nb
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import Diffusion_denoising_thin_slice.Build_lists.Build_list as Build_list
import Diffusion_denoising_thin_slice.functions_collection as ff
import Diffusion_denoising_thin_slice.Data_processing as Data_processing

# %% [markdown]
# ### brainCT

# %%
main_path = '/host/d/projects/denoising/pred_collections/brainCT'
patient_id = '00214841'
patient_subid = '0000455418'
slice_num = 25
center_x = 251
center_y = 252

save_folder = os.path.join('/host/d/projects/denoising/pictures/showcase/', 'brainCT_'+patient_id+'_' + patient_subid)
ff.make_folder([save_folder])

gt_img = nb.load(os.path.join(main_path, patient_id, patient_subid, 'gt_img.nii.gz')).get_fdata()
gt_img = gt_img[center_x - 200:center_x + 200, center_y - 200:center_y + 200, slice_num]
ff.save_grayscale_image(np.flip(gt_img.T,0),os.path.join(save_folder, 'gt_img_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 80)

condition_img = nb.load(os.path.join(main_path, patient_id, patient_subid, 'condition_img.nii.gz')).get_fdata()
condition_img = condition_img[center_x - 200:center_x + 200, center_y - 200:center_y + 200, slice_num]
ff.save_grayscale_image(np.flip(condition_img.T,0),os.path.join(save_folder, 'condition_img_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 80)

noise2noise_img = nb.load(os.path.join(main_path, patient_id, patient_subid, 'noise2noise_img.nii.gz')).get_fdata()
noise2noise_img = noise2noise_img[center_x - 200:center_x + 200, center_y - 200:center_y + 200, slice_num]
ff.save_grayscale_image(np.flip(noise2noise_img.T,0),os.path.join(save_folder, 'noise2noise_img_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 80)

noise2score_img = nb.load(os.path.join(main_path, patient_id, patient_subid, 'noise2score_img.nii.gz')).get_fdata()
noise2score_img = noise2score_img[center_x - 200:center_x + 200, center_y - 200:center_y + 200, slice_num]
ff.save_grayscale_image(np.flip(noise2score_img.T,0),os.path.join(save_folder, 'noise2score_img_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 80)

ddm2_finalstep_img = nb.load(os.path.join(main_path, patient_id, patient_subid, 'ddm2_finalstep_img.nii.gz')).get_fdata()
ddm2_finalstep_img = ddm2_finalstep_img[center_x - 200:center_x + 200, center_y - 200:center_y + 200, slice_num]
ff.save_grayscale_image(np.flip(ddm2_finalstep_img.T,0),os.path.join(save_folder, 'ddm2_finalstep_img_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 80)

supervised_img = nb.load(os.path.join(main_path, patient_id, patient_subid, 'supervised_img.nii.gz')).get_fdata()
supervised_img = supervised_img[center_x - 200:center_x + 200, center_y - 200:center_y + 200, slice_num]
ff.save_grayscale_image(np.flip(supervised_img.T,0),os.path.join(save_folder, 'supervised_img_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 80)

unsupervised_avg20_img = nb.load(os.path.join(main_path, patient_id, patient_subid, 'unsupervised_avg20_img.nii.gz')).get_fdata()
unsupervised_avg20_img = unsupervised_avg20_img[center_x - 200:center_x + 200, center_y - 200:center_y + 200, slice_num]    
ff.save_grayscale_image(np.flip(unsupervised_avg20_img.T,0),os.path.join(save_folder, 'unsupervised_avg20_img_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 80)

# %% [markdown]
# ### low-dose CT

# %%
main_path = '/host/d/projects/denoising/pred_collections/MAYO'
patient_id = 'L291'
slice_num = 85
center_x = 256
center_y = 256

roi_center_x = 122
roi_center_y = 278

save_folder = os.path.join('/host/d/projects/denoising/pictures/showcase/', 'mayo_'+patient_id)
ff.make_folder([save_folder])

gt_img = nb.load(os.path.join(main_path, patient_id,  'gt_img.nii.gz')).get_fdata()
gt_img_crop = gt_img[center_x - 250:center_x + 250, center_y - 250:center_y + 250, slice_num]
ff.save_grayscale_image(np.flip(gt_img_crop.T,0),os.path.join(save_folder, 'gt_img_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 400)

gt_img_roi = gt_img[roi_center_x - 50:roi_center_x + 50, roi_center_y - 50:roi_center_y + 50, slice_num]
ff.save_grayscale_image(np.flip(gt_img_roi.T,0),os.path.join(save_folder, 'gt_img_roi_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 400)


condition_img = nb.load(os.path.join(main_path, patient_id, 'condition_img.nii.gz')).get_fdata()
condition_img_crop = condition_img[center_x - 250:center_x + 250, center_y - 250:center_y + 250, slice_num]
ff.save_grayscale_image(np.flip(condition_img_crop.T,0),os.path.join(save_folder, 'condition_img_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 400)
condition_img_roi = condition_img[roi_center_x - 50:roi_center_x + 50, roi_center_y - 50:roi_center_y + 50, slice_num]
ff.save_grayscale_image(np.flip(condition_img_roi.T,0),os.path.join(save_folder, 'condition_img_roi_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 400)

noise2noise_img = nb.load(os.path.join(main_path, patient_id, 'noise2noise_img.nii.gz')).get_fdata()
noise2noise_img_crop = noise2noise_img[center_x - 250:center_x + 250, center_y - 250:center_y + 250, slice_num]
ff.save_grayscale_image(np.flip(noise2noise_img_crop.T,0),os.path.join(save_folder, 'noise2noise_img_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 400)
noise2noise_img_roi = noise2noise_img[roi_center_x - 50:roi_center_x + 50, roi_center_y - 50:roi_center_y + 50, slice_num]
ff.save_grayscale_image(np.flip(noise2noise_img_roi.T,0),os.path.join(save_folder, 'noise2noise_img_roi_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 400) 

noise2score_img = nb.load(os.path.join(main_path, patient_id, 'noise2score_img.nii.gz')).get_fdata()
noise2score_img_crop = noise2score_img[center_x - 250:center_x + 250, center_y - 250:center_y + 250, slice_num]
ff.save_grayscale_image(np.flip(noise2score_img_crop.T,0),os.path.join(save_folder, 'noise2score_img_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 400)
noise2score_img_roi = noise2score_img[roi_center_x - 50:roi_center_x + 50, roi_center_y - 50:roi_center_y + 50, slice_num]
ff.save_grayscale_image(np.flip(noise2score_img_roi.T,0),os.path.join(save_folder, 'noise2score_img_roi_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 400)

ddm2_finalstep_img = nb.load(os.path.join(main_path, patient_id, 'ddm2_finalstep_img.nii.gz')).get_fdata()
ddm2_finalstep_img_crop = ddm2_finalstep_img[center_x - 250:center_x + 250, center_y - 250:center_y + 250, slice_num]
ff.save_grayscale_image(np.flip(ddm2_finalstep_img_crop.T,0),os.path.join(save_folder, 'ddm2_finalstep_img_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 400)
ddm2_finalstep_img_roi = ddm2_finalstep_img[roi_center_x - 50:roi_center_x + 50, roi_center_y - 50:roi_center_y + 50, slice_num]
ff.save_grayscale_image(np.flip(ddm2_finalstep_img_roi.T,0),os.path.join(save_folder, 'ddm2_finalstep_img_roi_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 400)

supervised_img = nb.load(os.path.join(main_path, patient_id, 'supervised_img.nii.gz')).get_fdata()
supervised_img_crop = supervised_img[center_x - 250:center_x + 250, center_y - 250:center_y + 250, slice_num]
ff.save_grayscale_image(np.flip(supervised_img_crop.T,0),os.path.join(save_folder, 'supervised_img_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 400)
supervised_img_roi = supervised_img[roi_center_x - 50:roi_center_x + 50, roi_center_y - 50:roi_center_y + 50, slice_num]
ff.save_grayscale_image(np.flip(supervised_img_roi.T,0),os.path.join(save_folder, 'supervised_img_roi_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 400)   

unsupervised_avg20_img = nb.load(os.path.join(main_path, patient_id, 'unsupervised_avg10_img.nii.gz')).get_fdata()
unsupervised_avg20_img_crop = unsupervised_avg20_img[center_x - 250:center_x + 250, center_y - 250:center_y + 250, slice_num]    
ff.save_grayscale_image(np.flip(unsupervised_avg20_img_crop.T,0),os.path.join(save_folder, 'unsupervised_avg10_img_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 400)  
unsupervised_avg20_img_roi = unsupervised_avg20_img[roi_center_x - 50:roi_center_x + 50, roi_center_y - 50:roi_center_y + 50, slice_num]
ff.save_grayscale_image(np.flip(unsupervised_avg20_img_roi.T,0),os.path.join(save_folder, 'unsupervised_avg10_img_roi_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 400)

# %% [markdown]
# ### PCCT

# %%
main_path = '/host/d/projects/denoising/pred_collections/PCCT'
patient_id = '30'

slice_num = 24
center_x = 273
center_y = 203

save_folder = os.path.join('/host/d/projects/denoising/pictures/showcase/', 'PCCT_'+patient_id)
ff.make_folder([save_folder])


condition_img = nb.load(os.path.join(main_path, patient_id,  'original_image.nii.gz')).get_fdata()
condition_img = condition_img[center_x - 150:center_x + 150, center_y - 150:center_y + 150, slice_num]
ff.save_grayscale_image(np.flip(condition_img.T,0),os.path.join(save_folder, 'original_img_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 80)

# n2n_img = nb.load(os.path.join(main_path, patient_id, 'n2n_image.nii.gz')).get_fdata()
# n2n_img = n2n_img[center_x - 150:center_x + 150, center_y - 150:center_y + 150, slice_num]
# ff.save_grayscale_image(np.flip(n2n_img.T,0),os.path.join(save_folder, 'n2n_img_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 80)

# ddm2_firststep_img = nb.load(os.path.join(main_path, patient_id, 'ddm2_firststep_image.nii.gz')).get_fdata()
# ddm2_firststep_img = ddm2_firststep_img[center_x - 150:center_x + 150, center_y - 150:center_y + 150, slice_num]
# ff.save_grayscale_image(np.flip(ddm2_firststep_img.T,0),os.path.join(save_folder, 'ddm2_firststep_img_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 80)

# unsupervised_avg20_img = nb.load(os.path.join(main_path, patient_id, 'unsupervised_avg10_image.nii.gz')).get_fdata()
# unsupervised_avg20_img = unsupervised_avg20_img[center_x - 150:center_x + 150, center_y - 150:center_y + 150, slice_num]
# ff.save_grayscale_image(np.flip(unsupervised_avg20_img.T,0),os.path.join(save_folder, 'unsupervised_avg10_img_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 80)

# %%
main_path = '/host/d/projects/denoising/pred_collections/PCCT'
patient_id = '32'

slice_num = 5
center_x = 285
center_y = 221

save_folder = os.path.join('/host/d/projects/denoising/pictures/showcase/', 'PCCT_'+patient_id)
ff.make_folder([save_folder])


# condition_img = nb.load(os.path.join(main_path, patient_id,  'original_image.nii.gz')).get_fdata()
# condition_img = condition_img[center_x - 180:center_x + 180, center_y - 180:center_y + 180, slice_num]
# ff.save_grayscale_image(np.flip(condition_img.T,0),os.path.join(save_folder, 'original_img_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 80)

# n2n_img = nb.load(os.path.join(main_path, patient_id, 'n2n_image.nii.gz')).get_fdata()
# n2n_img = n2n_img[center_x - 180:center_x + 180, center_y - 180:center_y + 180, slice_num]
# ff.save_grayscale_image(np.flip(n2n_img.T,0),os.path.join(save_folder, 'n2n_img_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 80)

# ddm2_firststep_img = nb.load(os.path.join(main_path, patient_id, 'ddm2_firststep_image.nii.gz')).get_fdata()
# ddm2_firststep_img = ddm2_firststep_img[center_x - 180:center_x + 180, center_y - 180:center_y + 180, slice_num]
# ff.save_grayscale_image(np.flip(ddm2_firststep_img.T,0),os.path.join(save_folder, 'ddm2_firststep_img_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 80)

unsupervised_avg20_img = nb.load(os.path.join(main_path, patient_id, 'unsupervised_avg10_image.nii.gz')).get_fdata()
unsupervised_avg20_img = unsupervised_avg20_img[center_x - 180:center_x + 180, center_y - 180:center_y + 180, slice_num]
ff.save_grayscale_image(np.flip(unsupervised_avg20_img.T,0),os.path.join(save_folder, 'unsupervised_avg10_img_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 80)

# %%
main_path = '/host/d/projects/denoising/pred_collections/PCCT'
patient_id = '29'

slice_num = 17
center_x = 317
center_y = 236

save_folder = os.path.join('/host/d/projects/denoising/pictures/showcase/', 'PCCT_'+patient_id)
ff.make_folder([save_folder])


# condition_img = nb.load(os.path.join(main_path, patient_id,  'original_image.nii.gz')).get_fdata()
# condition_img = condition_img[center_x - 150:center_x + 150, center_y - 150:center_y + 150, slice_num]
# ff.save_grayscale_image(np.flip(condition_img.T,0),os.path.join(save_folder, 'original_img_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 80)

# n2n_img = nb.load(os.path.join(main_path, patient_id, 'n2n_image.nii.gz')).get_fdata()
# n2n_img = n2n_img[center_x - 150:center_x + 150, center_y - 150:center_y + 150, slice_num]
# ff.save_grayscale_image(np.flip(n2n_img.T,0),os.path.join(save_folder, 'n2n_img_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 80)

# ddm2_firststep_img = nb.load(os.path.join(main_path, patient_id, 'ddm2_firststep_image.nii.gz')).get_fdata()
# ddm2_firststep_img = ddm2_firststep_img[center_x - 150:center_x + 150, center_y - 150:center_y + 150, slice_num]
# ff.save_grayscale_image(np.flip(ddm2_firststep_img.T,0),os.path.join(save_folder, 'ddm2_firststep_img_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 80)

unsupervised_avg20_img = nb.load(os.path.join(main_path, patient_id, 'unsupervised_avg10_image.nii.gz')).get_fdata()
unsupervised_avg20_img = unsupervised_avg20_img[center_x - 150:center_x + 150, center_y - 150:center_y + 150, slice_num]
ff.save_grayscale_image(np.flip(unsupervised_avg20_img.T,0),os.path.join(save_folder, 'unsupervised_avg10_img_slice' + str(slice_num) + '.png'), normalize = True, WL = 40, WW = 80)
